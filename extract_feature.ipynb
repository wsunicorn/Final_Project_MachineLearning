# %% [markdown]
# # **Extract Features**

# %%
import os
import cv2
import numpy as np
import pandas as pd
from joblib import Parallel, delayed
from skimage.feature import local_binary_pattern, hog
from tqdm import tqdm


# === Hàm check nhãn từ tên file
def label_check(filename):
    filename = filename.lower()
    if 'fake' in filename:
        return 0
    elif 'real' in filename:
        return 1
    else:
        return -1

# === Hàm xử lý từng ảnh riêng biệt (sẽ chạy song song)
def process_single_image(full_path, label):
    try:
        img_gray = cv2.imread(full_path, cv2.IMREAD_GRAYSCALE)
        if img_gray is None:
            print(f"Không đọc được ảnh: {full_path}")
            return None

        img_resized = cv2.resize(img_gray, (300, 300), interpolation=cv2.INTER_AREA)

        
        # === FFT
        fft_image = np.fft.fft2(img_resized)
        fft_shifted = np.fft.fftshift(fft_image)
        magnitude_spectrum = np.log1p(np.abs(fft_shifted)).flatten()


        features_with_label = np.append(magnitude_spectrum, label)
        return features_with_label
        

    except Exception as e:
        print(f"Lỗi ảnh {full_path}: {e}")
        return None

# === Class trích xuất đặc trưng
class ExtractFeature:
    def __init__(self, path_origin, path_real, path_fake, label_image_csv):
        self.path = path_origin
        self.path_real = path_real.strip('/')
        self.path_fake = path_fake.strip('/')
        self.label_image = pd.read_csv(label_image_csv, header=None)

    def extract_all(self, num_jobs=4):
        args_list = []
        for filename in self.label_image[0]:
            label = label_check(filename)
            if label == -1:
                continue
            sub_path = self.path_fake if label == 0 else self.path_real
            full_path = os.path.join(self.path, sub_path, filename)
            args_list.append((full_path, label))

        print(f"{num_jobs} CPU...")

        results = Parallel(n_jobs=num_jobs)(
            delayed(process_single_image)(path, label)
            for path, label in tqdm(args_list)
        )

        # Lọc bỏ kết quả None
        data_extract = [r for r in results if r is not None]

        if not data_extract:
            print("Không có ảnh hợp lệ.")
            return pd.DataFrame()

        n_features = len(data_extract[0]) - 1
        columns = [f'f{i}' for i in range(n_features)] + ['label']
        return pd.DataFrame(data_extract, columns=columns)

# %%
path = '/kaggle/input/images/'
path_real = 'real'
path_fake = 'fake'
labels = 'labels.csv'

ex = ExtractFeature(path, path_real, path_fake, os.path.join(path, labels))
df = ex.extract_all(num_jobs=4)
df.head()
# Out:
# 4 CPU...
#  21%|██▏       | 732/3418 [00:17<00:40, 65.89it/s]libpng warning: iCCP: known incorrect sRGB profile
# 100%|██████████| 3418/3418 [01:04<00:00, 52.64it/s]
#          f0        f1        f2        f3        f4        f5        f6  \
# 0  5.455321  6.803012  6.916387  7.019597  7.634278  7.234165  6.689819
# 1  5.564520  7.426788  7.509238  6.901346  6.642542  6.653502  6.484016
# 2  6.811244  7.074574  7.338983  5.463220  6.503653  7.156263  5.934570
# 3  7.754053  5.491039  7.841576  6.719530  7.148400  6.776356  7.475415
# 4  7.696667  7.836997  6.493022  7.175246  7.635408  7.573038  6.198133
#
#          f7        f8        f9  ...    f89991    f89992    f89993    f89994  \
# 0  6.610899  5.848204  6.873254  ...  6.479335  5.476715  6.369600  6.943029
# 1  7.774878  6.894057  4.955522  ...  7.179169  6.195820  6.904962  7.480102
# 2  6.067958  6.150453  7.060361  ...  7.419872  6.891273  6.533821  6.884580
# 3  6.592669  7.079554  6.880515  ...  7.399733  6.923318  5.949911  7.636295
# 4  7.591490  7.263664  8.124040  ...  8.307859  6.059317  7.848695  7.411481
#
#      f89995    f89996    f89997    f89998    f89999  label
# 0  6.780847  4.482894  6.130951  7.052834  6.222040    0.0
# 1  5.364117  7.334429  7.826482  7.857921  6.698990    0.0
# 2  6.539111  6.051238  4.633889  7.473244  6.241400    0.0
# 3  7.625813  7.609264  7.557969  7.593189  6.494007    1.0
# 4  5.242786  7.150817  6.961332  5.870700  7.282219    1.0
#
# [5 rows x 90001 columns]

# %%
df.to_csv('features_handcraft.csv',index=False)
# Out:
# Không đọc được ảnh: /kaggle/input/images/fake/810101229_fake_dalleminibot_jungle_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199494_fake_dalle_jungle_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101243_fake_stable_mountain_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199584_fake_dall.e_sea_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810197238_fake_stable_jungle_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199311_fake_craiyon_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810701006_fake_delle_sea_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101293_fake_dalle_mountain_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/151501040_real_none_sea_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101229_fake_bing_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199424_fake_dalle_sea_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101224_fake_stable_sea_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199515_fake_DALL.E_mountain_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199311_fake_craiyon_jungle_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101149_fake_dalle_sea_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101293_fake_stable_sea_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810100473_fake_stable_sea_3.jpeg.png
# Không đọc được ảnh: /kaggle/input/images/fake/810199486_fake_dalle_sea_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198358_fake_stable_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/810100503_real_none_see_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101149_fake_stable_mountain_4.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101356_fake_dream_jungle_5.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101201_fake_dallemini_jungle_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199228_fake_midjourney_jungle_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101201_fake_dreamstudio_jungle_2.png
# Không đọc được ảnh: /kaggle/input/images/fake/810199456_fake_dalle_sea_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199460_fake_stable_mountain_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/830400052_fake_DallE_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199515_fake_stable_sea_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199228_fake_dreamstudio_sea_5.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810198346_fake_stable_mountain_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199492_fake_stable_jungle_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199228_fake_midjourney_sea_4.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199584_fake_dall.e_mountain_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198346_fake_DALLE_jungle_3.jpg
# Không đọc được ảnh: /kaggle/input/images/real/810101168_real_none_jungle_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101229_fake_bing_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199486_fake_dalle_mountain_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/610398217_real_none_mountain_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199460_fake_stable_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810197636_fake_dalle_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199436_fake_stable_jungle_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199494_fake_dalle_mountain_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199436_fake_dalle_sea_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101213_fake_stable_jungle_3.png
# Không đọc được ảnh: /kaggle/input/images/fake/810198429_fake_stable_jungle_4.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810701006_fake_dalle_jungle_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199424_fake_dalle_sea_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198429_fake_stable_sea_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199570_fake_dream_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199494_fake_dalle_sea_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810197238_fake_stable_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198358_fake_midjourney_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199456_fake_stable_mountain_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101229_fake_dalleminbot_sea_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199422_fake_stable_mountain_3.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810698270_fake_dreamstudio_sea_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/830401079_fake_DALL.E_forest_5.jpeg.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/810100363_Real_None_Jungle_8.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101251_fake_stable_mountain_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198358_fake_stable_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/830401079_fake_stable_mountain_3.jpeg.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810701006_fake_dalle_jungle_5.jpg
# Không đọc được ảnh: /kaggle/input/images/real/810100473_real_none_sea_3.jpeg.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101243_fake_dalle_sea_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199515_fake_stable_mountain_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810100457_fake_stable_sea_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101251_fake_dalle_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101213_fake_dalle_jungle_4.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199515_fake_DALL.E_jungle_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199494_fake_dalle_mountain_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101066_fake_dalle_mountain_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/150400011_real_none_mountain_8.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101224_fake_dall_forest_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101087_fake_stable_sea_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101213_fake_dalle_sea_3.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199424_fake_stable_jungle_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199460_fake_dalle_jungle_1.jpg
# Không đọc được ảnh: /kaggle/input/images/real/810100281_real_none_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101224_fake_stable_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199509_fake_dalle_jungle_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810100473_fake_dalle_sea_4.jpeg.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810197636_fake_stable_sea_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/810100363_Real_None_Mountain_2.jpg
# Không đọc được ảnh: /kaggle/input/images/real/150400011_real_none_sea_4.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/830400052_fake_DallE_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101251_fake_stable_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101233_fake_stable_jungle_9.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810100473_fake_stable_mountain_1.jpeg.png
# Không đọc được ảnh: /kaggle/input/images/fake/810101201_fake_dreamstudio_sea_5.png
# Không đọc được ảnh: /kaggle/input/images/real/610398217_real_none_sea_9.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101251_fake_stable_jungle_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/810101201_real_none_jungle_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/810101168_real_none_jungle_8.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199228_fake_dreamstudio_jungle_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101229_fake_dalleminibot_mountain_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199492_fake_stable_jungle_5.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/81099311_fake_stable_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198358_fake_midjourney_jungle_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199509_fake_stable_jungle_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/810101066_real_none_mountain_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199492_fake_dalle_jungle_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101356_fake_dalle_sea_4.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810998099_fake_dalle_mountain_3.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810100473_fake_stable_sea_4.jpeg.png
# Không đọc được ảnh: /kaggle/input/images/fake/810101213_fake_stable_sea_1.png
# Không đọc được ảnh: /kaggle/input/images/fake/810197238_fake_stable_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199422_fake_dalle_jungle_5.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101149_fake_dalle_mountain_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810198429_fake_DALLE_jungle_4.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199486_fake_stable_jungle_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199570_fake_dalle_mountain_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101233_fake_stable_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199567_fake_stable_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101168_fake_dalle_jungle_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/810100284_real_none_jungle_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810998099_fake_dalle_jungle_1.jpg
# Không đọc được ảnh: /kaggle/input/images/real/810100284_real_none_jungle_9.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/610398217_real_none_mountain_9.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101066_fake_stable_sea_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/151501040_real_none_jungle_8.jpg
# Không đọc được ảnh: /kaggle/input/images/real/810100281_real_none_sea_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101229_fake_dalleminibot_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198375_fake_dalle_jungle_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199492_fake_stable_sea_5.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101201_fake_dreamstudio_sea_1.png
# Không đọc được ảnh: /kaggle/input/images/real/151501040_real_none_mountain_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101224_fake_stable_forest_5.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199427_fake_stable_jungle_8.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199456_fake_dalle_sea_5.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810100473_fake_stable_jungle_2.jpeg.png
# Không đọc được ảnh: /kaggle/input/images/fake/810100457_fake_stable_mountain_1.jpg
# Không đọc được ảnh: /kaggle/input/images/real/810100281_real_none_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198346_fake_stable_jungle_4.jpg
# Không đọc được ảnh: /kaggle/input/images/real/151501040_real_none_mountain_10.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/830401079_fake_stable_sea_4.jpeg.jpg
# Không đọc được ảnh: /kaggle/input/images/real/810101087_real_none_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/830401079_fake_DALL.E_sea_3.jpeg.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199509_fake_stable_sea_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198375_fake_stable_mountain_3.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810698270_fake_dalle_mountain_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810998099_fake_stable_mountain_2.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101229_fake_bing_sea_1.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101293_fake_stable_jungle_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/real/151501040_real_none_sea_5.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810100503_fake_dalle_see_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810198358_fake_midjourney_mountain_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101114_fake_stable_sea_4.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199427_fake_stable_sea_6.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199422_fake_stable_sea_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810101213_fake_stable_sea_5.png
# Không đọc được ảnh: /kaggle/input/images/fake/810199228_fake_dreamstudio_sea_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199486_fake_stable_mountain_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810101224_fake_dall_mountain_3.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810701006_fake_dalle_mountain_1.jpg
# Không đọc được ảnh: /kaggle/input/images/fake/810199424_fake_dalle_mountain_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810197636_fake_stable_mountain_2.jpeg
# Không đọc được ảnh: /kaggle/input/images/fake/810199584_fake_stable_ju

# %%
X = df.drop('label', axis=1)
y = df['label']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=512)
X_pca = pca.fit_transform(X_scaled)

# %%
# Gộp lại PCA features với nhãn
features_pca = pd.DataFrame(X_pca)
features_pca['label'] = y.values  # thêm cột label vào cuối

# Lưu ra file CSV chứa feature và labels
features_pca.to_csv('features_handcraft_pca.csv', index=False)
